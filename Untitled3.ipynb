# %% [markdown]
# ## KNN(k-Nearest Neighbors) Latest Neighbor Algorithm

# %%
Assign K a Value - preferably a small odd number (K = 3)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# Find K items with lowest distances to new pont (K = 3)
